# %% [markdown]
# # Imports:

# %%
import requests
import pandas as pd
import time

# %% [markdown]
# # Scraping:

# %%
# Kelt light curve API:
url = 'https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=kelttimeseries&format=json&kelt_field=N02&where=kelt_mag%3C11'
# 'https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=kelttimeseries&format=json&kelt_field=N02&where=kelt_mag%3C11'

#'https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=k2targets&format=json'
#'https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=k2targets'
    
res = requests.get(url, headers = {'User-agent': 'Zachman'})
if res.status_code != 200:
    print('Status code error!!!', res.status_code)
#     break
print(url)
# Out:
# https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI?table=kelttimeseries&format=json&kelt_field=N02&where=kelt_mag%3C11

# %%
current_dict = res.json()

# %%
current_dict;

# %% [markdown]
# # Prepare and Save

# %%
# Convert to a dataframe
scrapings = pd.DataFrame(current_dict)
scrapings.shape
# Out:
# (354, 24)

# %%
scrapings.head().T
# Out:
#                                              0                            1  \
# bjdstart                           2.45403e+06                  2.45404e+06
# bjdstop                            2.45479e+06                  2.45479e+06
# chisquared                             18610.8                        50740
# dec                                    20.0673                      20.0673
# f5sigma                                0.00558                     0.001661
# kelt_field                                 N02                          N02
# kelt_mag                                10.416                       10.337
# kelt_orientation                          east                         west
# kelt_proc_version                          V01                          V01
# kelt_sourceid      KELT_N02_lc_001388_V01_east  KELT_N02_lc_001388_V01_east
# maxvalue                                12.738                      13.1789
# ...

# %%
# Save to csv
# subreddit_df.to_csv('jokes_posts.csv', index = False)

# %%
# Comments from previous file

#     current_posts = [p['data'] for p in current_dict['data']['children']]
#     posts.extend(current_posts)
#     after = current_dict['data']['after']
    
    # print URL to give us feedback on progress, then give the API a rest
    
#     time.sleep(1)

# posts = []
# after = None

# for _ in range(100):
    
#     # Set the URL to the correct value
#     if after == None:
#         current_url = url
#         if _ != 0:
#             break
#     else:
#         current_url = url + '?after=' + after
        
    #get info about posts from the API
